# %%
#imports
import plotly.express as px
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Import your groupMetadataID below

# %%
#set intial groupMetadataID
gmID = '1bbbfbae-c839-11ee-a7fc-dd032dba19e8'

#if data is stored as .csv file set to False
#else set to True

if os.path.isfile(f"../data/chassis/{gmID}.csv"):
    queryChassis = False
    print("chassis csv file found!")
else:
    queryChassis = True
    print("chassis csv file not found. Query for data necessary.")


if os.path.isfile(f"../data/best_pose/{gmID}.csv"):
    queryPose = False
    print("best_pose csv file found!")
else:
    queryPose = True
    print("best_pose csv file not found. Query for data necessary.")


if os.path.isfile(f"../data/metadata/{gmID}.csv"):
    queryMeta = False
    print("metadata csv file found!")
else:
    queryMeta = True
    print("metadata csv file not found. Query for data necessary.")
# Out:
# chassis csv file not found. Query for data necessary.
# best_pose csv file found!
# metadata csv file not found. Query for data necessary.

# %%
from boto3.dynamodb.conditions import Key,Attr
import boto3

if queryPose or queryChassis or queryMeta:
    dynamodb = boto3.resource('dynamodb')
    table = dynamodb.Table('ads_passenger_processed')
    table_meta =dynamodb.Table('ads_passenger_processed_metadata')

# %%
if not os.path.exists(f"../data/best_pose"):
    os.makedirs(f"../data/best_pose")

if queryPose:

    #query arguments for best_pose data
    keywords = dict(
        IndexName='topic-index',
        KeyConditionExpression=Key('topic').eq(
            '/apollo/sensor/gnss/best_pose'),
        ProjectionExpression="groupMetadataID, #t, solStatus, solType, latitudeStdDev, longitudeStdDev, numSatsTracked, numSatsMulti, numSatsInSolution, differentialAge, solutionAge, latitude, longitude",
        Limit=1500,
        ExpressionAttributeNames={'#t': 'time'},
        FilterExpression=Key('groupMetadataID').eq(f'{gmID}')
    )


    #run query for best_pose data and create dataframe
    res = table.query(**keywords)
    df_pose = pd.DataFrame.from_dict(
        pd.json_normalize(res['Items']),orient='columns')

    done = False
    leek = res["LastEvaluatedKey"]

    while not done:
        try:
            leek = res["LastEvaluatedKey"]
            keywords["ExclusiveStartKey"] = leek
            res = table.query(**keywords)
            tmpDF = pd.DataFrame.from_dict(
                pd.json_normalize(res['Items']), orient='columns')
            df_pose = pd.concat([df_pose, tmpDF])
        except KeyError:
            print("Done querying best_pose data")
            done = True

    df_pose.to_csv(f"../data/best_pose/{gmID}.csv")
    print(f"Saved best_pose data at ../data/best_pose/{gmID}.csv")


else:
    df_pose = pd.read_csv(f"../data/best_pose/{gmID}.csv")
    print("Loaded best_pose data")
            
        
print(df_pose.shape)
# Out:
# Loaded best_pose data
# (165, 14)

# %%
if not os.path.exists(f"../data/chassis"):
    os.makedirs(f"../data/chassis")

if queryChassis:
    
    #query arguments for chassis data
    keywords = dict(
        IndexName='topic-index',
        KeyConditionExpression=Key('topic').eq(
            '/apollo/canbus/chassis'),
        Limit=2000,
        FilterExpression=Key('groupMetadataID').eq(gmID)
    )

    res = table.query(**keywords)
    df_chassis = pd.DataFrame.from_dict(
        pd.json_normalize(res['Items']), orient='columns')

    done = False
    leek = res["LastEvaluatedKey"]

    while not done:
        try:
            leek = res["LastEvaluatedKey"]
            keywords["ExclusiveStartKey"] = leek
            res = table.query(**keywords)
            tmpDF = pd.DataFrame.from_dict(
                pd.json_normalize(res['Items']), orient='columns')
            df_chassis = pd.concat([df_chassis, tmpDF])
            print(leek)

        except KeyError:
            print(f"done querying for chassis data")
            done = True

    df_chassis.to_csv(f"../data/chassis/{gmID}.csv")
    print(f"Saved chassis data at ../data/chassis/{gmID}.csv")
else:
    df_chassis = pd.read_csv(f"../data/chassis/{gmID}.csv")
    print("Loaded chassis data")

print(df_chassis.shape)
# Out:
# {'_id': 'cc82e50c-db4a-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692301504388532934')}
# {'_id': '15fa05e3-d2a4-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698253449947109077')}
# {'_id': '70806656-a520-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695933146014667852')}
# {'_id': '94f1f0b4-cb84-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696533741090559411')}
# {'_id': '2b7bfbf6-cb92-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697138242295307523')}
# {'_id': '86676011-cb83-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696533657411429261')}
# {'_id': '27327ff6-a51a-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695932808855487870')}
# {'_id': '1c9d1502-c867-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694625122048416187')}
# {'_id': '1e2dcbe6-ca9b-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695838505179368647')}
# {'_id': '1e145f18-cafc-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697651599968987329')}
# {'_id': '467053a0-d991-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685639569821142141')}
# {'_id': 'e5c645d4-cad0-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696873497753610775')}
# {'_id': 'bcde63fd-c881-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695836814180160932')}
# {'_id': '1fad7820-caa0-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696436592720938494')}
# {'_id': 'b939d96d-a516-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695932620436047886')}
# {'_id': '728677b3-d302-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706302628109702771')}
# {'_id': '292069b3-a432-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685541947988853932')}
# {'_id': '3cb6d605-a412-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674155967975190674')}
# {'_id': '8c86b53d-dc18-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693925940502066590')}
# {'_id': 'aa7ae527-a4d7-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694451633693542090')}
# {'_id': '4aa12932-d35d-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698348066226215912')}
# {'_id': 'bee02889-a50e-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695932152518871255')}
# {'_id': '1345f348-d32c-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698081661427448564')}
# {'_id': 'aa957f7c-d99d-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689271045235484853')}
# {'_id': '1f32323b-c867-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694625123005038686')}
# {'_id': 'd8e12750-d9d2-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1691505121339102465')}
# {'_id': 'beca82b0-dbe3-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693500010843268413')}
# {'_id': 'c534825e-a40e-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674155739974198401')}
# {'_id': 'b717ee71-d308-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706303133816388092')}
# {'_id': 'f67f49f3-d2dd-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706299339556494643')}
# {'_id': '16859f1b-d9ae-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690478786568078580')}
# {'_id': 'cc3d8ca3-caa1-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696436713980846184')}
# {'_id': 'd3482985-a433-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683313893290273837')}
# {'_id': 'bc588091-cb8d-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697137874175251427')}
# {'_id': '5f1736a0-db31-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692289163090578154')}
# {'_id': '07676b58-d352-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698256666476238844')}
# {'_id': 'b98b594e-d9bd-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690481204713027951')}
# {'_id': '2125ec4a-c879-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695228762430136876')}
# {'_id': 'd9676c07-d9ae-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690478889788578130')}
# {'_id': 'fec45042-d352-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698256752755689780')}
# {'_id': 'e6b5572a-db42-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692300392924365669')}
# {'_id': '74f4eb38-dc07-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693508109930526196')}
# {'_id': 'bd454b90-cab8-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696871807354360071')}
# {'_id': 'cf6ab7f4-a420-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674156866718663394')}
# {'_id': 'bb25b7a0-d2c6-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705954554436927814')}
# {'_id': '5345af67-d346-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698255653996801991')}
# {'_id': '46dc336d-d9d4-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1691505328943417479')}
# {'_id': '699e3308-cafa-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697651463288904104')}
# {'_id': '13e89019-c87e-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695229201389385623')}
# {'_id': '786bac41-cbb0-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697743390483876497')}
# {'_id': '3d2e3c27-d2e9-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706300245336282617')}
# {'_id': 'f542e86d-a437-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683315130970700510')}
# {'_id': 'ff91e5c4-cae9-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697478279890652258')}
# {'_id': '61b7d384-cac5-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872687193724556')}
# {'_id': '479cb56a-dbf3-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693502745998908098')}
# {'_id': '5b16d4a1-cad7-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697476822410495662')}
# {'_id': 'dcc2cf96-dc2b-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693929243202612000')}
# {'_id': 'a7303ef2-a439-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1684775833117581067')}
# {'_id': '337a1622-d349-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698255900497584505')}
# {'_id': '85c07db6-cb87-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696533974169245960')}
# {'_id': '0c308022-cae8-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697478127249511399')}
# {'_id': '9408df7b-d9c7-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690482747562608187')}
# {'_id': '1824b202-d351-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698256582875564318')}
# {'_id': '63e0df3c-d335-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698082413627066941')}
# {'_id': '9b782bde-d9b6-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690479977402899310')}
# {'_id': 'a61221c2-ca8b-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695837298000274359')}
# {'_id': '0c307f2b-cae8-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697478126969536599')}
# {'_id': '270a4dda-a437-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683314871830708356')}
# {'_id': '269f4415-a5f4-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697473969084498350')}
# {'_id': '7bb01825-d2d3-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705955535096322206')}
# {'_id': 'cee266a6-caee-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697650546488224572')}
# {'_id': '7f807a48-d34b-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698256095275931202')}
# {'_id': 'fbbd2c5f-a53b-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696266191603770280')}
# {'_id': 'bbaef6cd-cae9-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697478258330435315')}
# {'_id': '3dfc8a8f-a436-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683314608491347407')}
# {'_id': 'd8c6b887-cb94-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697138469176253367')}
# {'_id': '7b776028-d2ee-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706300663635592983')}
# {'_id': 'd2f8c0e8-a4c7-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694450623992494222')}
# {'_id': 'd8a0ffa2-d283-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698079684857994690')}
# {'_id': 'e24315a5-a602-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697474442285758513')}
# {'_id': '6666d164-d32d-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698081754945411893')}
# {'_id': '217741ea-db5a-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693496044546664253')}
# {'_id': '1ee894de-cae1-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697477589949963201')}
# {'_id': '706b4521-d2ec-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706300503474997272')}
# {'_id': '73d63e67-d2ad-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705952290114778522')}
# {'_id': 'd86cb636-db48-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692301228813274021')}
# {'_id': '3bed7744-c866-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694625040884016305')}
# {'_id': '64fc6ce0-d34a-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698256001476826817')}
# {'_id': '973ecfe2-d9a4-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689271943264347571')}
# {'_id': '55f5408c-dc07-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693508096369115244')}
# {'_id': '56899c41-a50e-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695932126794330005')}
# {'_id': '407c40c0-cb5b-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695324150166340019')}
# {'_id': '9e7e6cfa-cb93-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697138363255973603')}
# {'_id': '07f37964-cbaa-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697742820944165644')}
# {'_id': '6e484bcd-d341-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698255239634897695')}
# {'_id': 'acc87b89-cb9e-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697139460036374641')}
# {'_id': 'ef22c5bb-d28e-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698251744429790107')}
# {'_id': '8573139e-cb84-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696533735849801975')}
# {'_id': 'c7c026be-dbed-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693502161683913974')}
# {'_id': '7f55e1af-a4f2-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695055136322453111')}
# {'_id': 'c45bec2d-d2d4-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705955631454741263')}
# {'_id': '783c5936-dc0a-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693508418522954439')}
# {'_id': '88b2751e-d9bf-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690481464384534270')}
# {'_id': 'fa5267fe-a434-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683314232650346507')}
# {'_id': '7a028b31-d2b1-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705952609635426795')}
# {'_id': 'e87661cd-cb9a-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697139155996233071')}
# {'_id': '06464e4b-d2cf-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705955197375245339')}
# {'_id': '529330c5-cbb0-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697743378301311453')}
# {'_id': 'b59bb619-a417-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674156306715490211')}
# {'_id': 'c6bedfcc-a4e2-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694452307383896002')}
# {'_id': '1e75ef63-cafe-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697651761348834017')}
# {'_id': 'a31c27ef-d2d5-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705955698074767208')}
# {'_id': 'd634682e-c87e-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695229270368505570')}
# {'_id': '102eb8f7-d300-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706302435335201862')}
# {'_id': 'dd07004d-c86f-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695227967249801663')}
# {'_id': 'ea5262ed-d987-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685632913092366366')}
# {'_id': 'f570ba87-d28e-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698251746668249971')}
# {'_id': 'c2513e66-db30-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692289024337490919')}
# {'_id': '24379828-d27a-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698078948239497082')}
# {'_id': 'aa71e78c-ca8e-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695837530019415457')}
# {'_id': 'a5115bc6-d357-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698347584845161898')}
# {'_id': 'ace5833f-cab1-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696437917401870055')}
# {'_id': '65d3e0a6-d292-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698252025446861534')}
# {'_id': 'b9e4d11b-d278-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698078844859152594')}
# {'_id': '54bf3a89-d997-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685640415247708062')}
# {'_id': 'ede5e702-db4c-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692301805578116556')}
# {'_id': '961dac0e-d33d-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698254907495201127')}
# {'_id': '409d4f80-dc25-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693928556543408756')}
# {'_id': 'c40b31ad-cae1-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697477639070466008')}
# {'_id': '88e1fb66-db45-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692300757992476668')}
# {'_id': '1d4903c6-d983-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685632267436191491')}
# {'_id': '51e10ee6-a52c-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696265479203844317')}
# {'_id': '4a0b5846-a4eb-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695054645202469338')}
# {'_id': 'de9a3770-d28f-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698251819606922529')}
# {'_id': 'ee317498-a4fa-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695055704002977714')}
# {'_id': '69f7fc24-d9b0-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690479110494359862')}
# {'_id': '86747a69-db45-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692300756182420406')}
# {'_id': '803884f6-d2da-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705956068534840150')}
# {'_id': '1c378dc7-a40d-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674155629155732787')}
# {'_id': '4d142ca6-a536-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696265937184212857')}
# {'_id': 'ae8a7933-d9c6-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690482622386948303')}
# {'_id': '8231ca01-a5e5-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697473485347939818')}
# {'_id': '8e23f4c8-a5fe-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697474303684451573')}
# {'_id': '00bc88c2-c87d-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695229101731038831')}
# {'_id': '760eb1ac-a4e5-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694452474713259017')}
# {'_id': '27e73e3a-a4c9-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694450714273492016')}
# {'_id': '539533cc-c87b-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695228955689949263')}
# {'_id': '9fa85e86-d9ce-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690483701684807334')}
# {'_id': '829bd47e-cac5-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872696633221927')}
# {'_id': '500d6a49-d320-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706908130433800719')}
# {'_id': '124c5179-d31f-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706908028613914701')}
# {'_id': '72c86715-cb6e-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695928221452970556')}
# {'_id': 'e32ed754-dbf3-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693502810427268218')}
# {'_id': 'abc72fde-d99f-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689271281318043226')}
# {'_id': '0fee4f43-a5b3-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696869173373959705')}
# {'_id': 'f1155029-a431-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685541886368757193')}
# {'_id': '28e2aa1a-dbe0-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693499634114536741')}
# {'_id': 'c5660586-cae5-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697477947690376242')}
# {'_id': '8cc00746-a5cd-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696870166680146552')}
# {'_id': 'f32ff3e1-a50b-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695931969735089951')}
# {'_id': '5b50871c-a644-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697648826338851941')}
# {'_id': 'ea6c4e62-a5c2-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696869775793672692')}
# {'_id': 'e66b1412-cbaa-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697742889645290054')}
# {'_id': 'e56b93ca-a43b-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1684776005741597414')}
# {'_id': 'eb475bbd-d2ab-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705952167974757625')}
# {'_id': 'eea2baf8-a4ed-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695054827342597631')}
# {'_id': '3cb2b549-d9ca-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690483093989097625')}
# {'_id': 'ccc8831b-c868-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694625270705314205')}
# {'_id': 'ef1e9e01-caf2-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697650872087582830')}
# {'_id': '21cbbbba-d31b-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706907704274483449')}
# {'_id': '7efe1e40-db3e-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692299037279604863')}
# {'_id': '1746a8c5-db32-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692289344672254613')}
# {'_id': 'dbfdfc60-d2e7-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706300133256344440')}
# {'_id': '6a160165-cafd-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697651703668848624')}
# {'_id': '4b8903e3-a51a-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695932815354814692')}
# {'_id': 'ae996bad-a64e-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697649114739669411')}
# {'_id': 'ff0e8582-d29b-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698252796301324912')}
# {'_id': 'f0d6ef44-db40-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692300108358547864')}
# {'_id': '427b9339-cba9-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697742757804203097')}
# {'_id': '3e5bf7fb-db4b-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692301565980771815')}
# {'_id': '3cef6a94-caa7-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696437116600034391')}
# {'_id': '211baec8-a4e4-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694452392093254372')}
# {'_id': '7b411110-cb64-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695324849685417935')}
# {'_id': 'ee335743-db49-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692301379220217633')}
# {'_id': '8985e7fc-d9a8-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689272492323223633')}
# {'_id': '770e3635-d9a8-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689272481658985902')}
# {'_id': 'd2664944-cac6-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872790253641512')}
# {'_id': '19a9309c-a532-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696265746183787065')}
# {'_id': '1e4408a9-c861-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694624576745409794')}
# {'_id': '677a8387-d2e0-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706299536236181286')}
# {'_id': '1d9a0654-d2f3-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706301036596179131')}
# {'_id': 'adac9de8-d275-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698078634599449039')}
# {'_id': '127b3659-d33b-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698082894547341887')}
# {'_id': '25b7d464-dc17-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693509737492104799')}
# {'_id': 'd121cbbf-d298-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698252542288425715')}
# {'_id': 'a480e2cc-a43c-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1684776069877685649')}
# {'_id': '7203ff50-d274-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698078554279549887')}
# {'_id': 'e17598f8-cb89-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696534155110177971')}
# {'_id': 'f8323714-c85e-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694624384704316905')}
# {'_id': 'a726b9ed-d2bd-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705953558494739963')}
# {'_id': 'd9dbc605-db2f-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692288792514194135')}
# {'_id': '56631fb1-cba9-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697742764605293251')}
# {'_id': '0b7a9163-cb57-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694719311387802369')}
# {'_id': 'b155653a-a4ea-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695054603842467661')}
# {'_id': 'ce321a61-d331-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698082114307439023')}
# {'_id': 'ff486329-a43c-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1684776098857653941')}
# {'_id': '1cc1b49b-a64b-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697649016180126204')}
# {'_id': 'cc47d5a0-a4ce-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694451091033103992')}
# {'_id': 'c6169294-d281-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698079533059390109')}
# {'_id': '4abbae1f-d2ab-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705952120076591753')}
# {'_id': '65ea6060-a4c9-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694450730493639848')}
# {'_id': 'e7c3ad58-cadf-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697477492729116540')}
# {'_id': '9a0d3001-d356-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698347493926392839')}
# {'_id': '3ac86174-db53-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693495163248407076')}
# {'_id': '49841bc0-cadc-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697477206570545531')}
# {'_id': 'cc361ce4-a4f6-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695055422881807579')}
# {'_id': '4192a2bd-cabf-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872280097611969')}
# {'_id': '4327f1cd-d996-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685640262853733137')}
# {'_id': 'ac6164ad-d9a1-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689271537859806723')}
# {'_id': '45e5519f-cb66-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695927586755079291')}
# {'_id': '1e9c4ce3-d336-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698082473785746804')}
# {'_id': '7539c984-cbaf-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697743307103884710')}
# {'_id': 'cbb8c9c0-dc0a-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693508453857257335')}
# {'_id': '9d3e6e8c-cabb-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872018173722789')}
# {'_id': '9d6d03ef-db4e-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693494538261597889')}
# {'_id': 'a11d845f-dbed-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693502139746649250')}
# {'_id': '0d3e41b5-cab0-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696437793220921219')}
# {'_id': 'd12e7a06-d2c0-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705953811674710373')}
# {'_id': '1e660ce8-a434-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683313980989802411')}
# {'_id': '5ef63e3e-ca9c-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695838610740610447')}
# {'_id': '62517f78-d2b0-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705952523594658180')}
# {'_id': '9b8713c0-a5b4-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696869232814230494')}
# {'_id': '56ad33d8-a5c7-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696869941513627635')}
# {'_id': 'c452d34b-cae3-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697477791569981530')}
# {'_id': '6c3daa92-ca92-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695837823939351963')}
# {'_id': 'eb866b21-a4fd-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695055906342515582')}
# {'_id': 'a7c123da-a42b-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674157521733509598')}
# {'_id': 'fb5bcc2c-cb62-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695324737026598857')}
# {'_id': '5c06e97b-caa5-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696436976700924964')}
# {'_id': '0b353459-dc18-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693925883736277828')}
# {'_id': '9efcebf6-d9a4-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689271947653317211')}
# {'_id': '5b612e06-cad4-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697476592310575862')}
# {'_id': '25fb1e2a-d32e-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698081814387372177')}
# {'_id': '4d2c8f3a-d2e6-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706300009296095533')}
# {'_id': 'c4098fda-a41c-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674156619575177492')}
# {'_id': '4c8b548a-c87d-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695229129209464507')}
# {'_id': '6a26d5af-db4a-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692301448154559634')}
# {'_id': 'fe3777bc-a506-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695931638998065297')}
# {'_id': 'e8c30ecf-a5b5-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696869284073656465')}
# {'_id': '856e582b-c87d-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695229149130075771')}
# {'_id': 'adf436d3-cafa-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697651484648059014')}
# {'_id': 'cde283dc-caf4-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697651021448074187')}
# {'_id': '2d753c38-d318-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706907459215000174')}
# {'_id': '9352b925-cacb-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696873127913996595')}
# {'_id': 'e9e4403d-cae8-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697478194989246637')}
# {'_id': 'af45c398-d35e-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698348181165881860')}
# {'_id': 'a7d1d6b2-a4e2-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694452300433291927')}
# {'_id': 'cbbc0db8-d329-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698081492427449446')}
# {'_id': 'a556cbda-d9d1-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1691504934524298503')}
# {'_id': '2b198840-cbb3-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697743613084661797')}
# {'_id': '90f732d6-dc07-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693508120931469620')}
# {'_id': '556ebc34-cada-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697477051010564067')}
# {'_id': 'a2a16c59-db35-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692297916595016449')}
# {'_id': 'd36c971f-a419-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674156438534121760')}
# {'_id': 'fbd38dcf-a4ff-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695056045482498527')}
# {'_id': '40171873-cb92-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697138248516245099')}
# {'_id': '0f5ad033-a5bd-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696869553156878391')}
# {'_id': '5323b7a8-a437-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683314927590847848')}
# {'_id': '60242867-a544-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696266557083782959')}
# {'_id': 'e17665d6-a5b6-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696869321293824758')}
# {'_id': '376abe8a-d2d3-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705955515055553020')}
# {'_id': '3098772d-d318-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706907459958334250')}
# {'_id': '9c733116-a433-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683313831649434769')}
# {'_id': '4e8788f4-d280-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698079417908048637')}
# {'_id': '938e50c9-d295-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698252279548266084')}
# {'_id': '22d7942d-db1d-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692284150440467768')}
# {'_id': '041968c8-c873-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695228240329775586')}
# {'_id': '750303f9-cacc-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696873188073057521')}
# {'_id': '5c884ec2-d2ce-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705955146455873475')}
# {'_id': '554e8697-db52-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693495052424311248')}
# {'_id': '4934844f-dc26-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693928663855836072')}
# {'_id': 'bd9590d4-cb7d-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696532978072058345')}
# {'_id': 'd6a76e78-d2f0-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706300851936086889')}
# {'_id': '72548c57-d2a4-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698253477706215041')}
# {'_id': '2710df96-d2df-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706299433416053422')}
# {'_id': 'c7e490c0-a50b-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695931958595469287')}
# {'_id': '4e259ec7-c865-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694624954564467242')}
# {'_id': '88780079-d2c0-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705953788174647358')}
# {'_id': '08b4ffe2-d2cd-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705955046754747605')}
# {'_id': 'ac827d8c-d2b6-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705953021055281383')}
# {'_id': '00a792cb-db46-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692300825443698086')}
# {'_id': '0efdef56-db54-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693495261774570509')}
# {'_id': 'fb5fed3e-d9a4-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689271997327610244')}
# {'_id': '76058961-db45-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692300747556115488')}
# {'_id': '66741df2-caeb-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697478397810461763')}
# {'_id': 'e7b25ba6-c862-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694624736348129650')}
# {'_id': 'e42b7348-d9c0-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690481652650354105')}
# {'_id': '5fcdb4a0-a421-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674156901415399574')}
# {'_id': '3c147c7c-c86d-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695227730589171280')}
# {'_id': '50cddce7-d356-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698347468946613762')}
# {'_id': '35ab70b3-a518-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695932701114524211')}
# {'_id': 'f261a44c-caa3-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696436869780410738')}
# {'_id': 'f08bddd2-d2dd-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706299338356384325')}
# {'_id': '294bc638-cba2-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697742176843129316')}
# {'_id': '91df2799-cabb-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872014953185086')}
# {'_id': 'b3e4952d-d2ff-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706302405618257634')}
# {'_id': '84978041-d34b-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698256096400666484')}
# {'_id': 'eef145bd-cab6-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696438330459526082')}
# {'_id': '941e53f5-a533-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696265814403808683')}
# {'_id': 'b3b5927d-a4e7-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695054393842442046')}
# {'_id': '957c5208-d9b6-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690479973542446757')}
# {'_id': 'e3fa114a-d339-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698082789647396763')}
# {'_id': '88104c04-d9b3-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690479545603235048')}
# {'_id': '17d8e7cc-d279-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698078870519581555')}
# {'_id': '2bfa9c0e-d28c-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698080321758177911')}
# {'_id': '893c6c29-db43-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692300480167384019')}
# {'_id': '0450e53f-cb55-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694719146031246506')}
# {'_id': '734f0093-d31b-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706907730783815679')}
# {'_id': '22d65089-d35a-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698347797026350725')}
# {'_id': '874ae0d4-d363-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698348587865917511')}
# {'_id': '8eaa7227-d314-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706907161733342712')}
# {'_id': '2e253560-a61f-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697475298704522405')}
# {'_id': '26f57dea-cba1-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697742095604510678')}
# {'_id': 'ae1410de-cacd-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696873272774268145')}
# {'_id': 'cf09f1ce-a4d7-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694451641894759614')}
# {'_id': 'af20276e-d9c2-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690481907708451684')}
# {'_id': '70a1c84e-c87a-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695228878148858271')}
# {'_id': 'd7ca6be6-cafd-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697651738689257755')}
# {'_id': '1f231eb1-d9a9-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689272574657812241')}
# {'_id': '1198aa96-a4dc-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694451900993959571')}
# {'_id': '0dc612b2-dbf6-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693503034642801840')}
# {'_id': '5ef8f8b2-a5f1-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697473874161860636')}
# {'_id': 'afb3e6c6-cac5-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872709215658938')}
# {'_id': 'dc1f099b-a507-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695931697774776506')}
# {'_id': '6286e9f2-dbd8-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693498811819454616')}
# {'_id': '9ff87360-cb5b-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695324178585968212')}
# {'_id': '0b9db1e0-a5fa-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697474157964839500')}
# {'_id': '2afa214c-a4f3-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695055178962649015')}
# {'_id': '72a38488-dc1d-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693926450372599697')}
# {'_id': '36b3d50b-a611-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697474886404421792')}
# {'_id': '56a614f4-caf8-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697651301147671977')}
# {'_id': 'f676e31f-a437-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683315132430845035')}
# {'_id': '42bdb9f6-cb56-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694719247388656343')}
# {'_id': 'f2710ab1-db2f-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692288809112029959')}
# {'_id': '382af56d-d9a3-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689271757377990177')}
# {'_id': '22bc7f50-a5ba-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696869445613631774')}
# {'_id': '8761675d-d2ee-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706300667235672893')}
# {'_id': '8eae97e3-ca8c-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695837368180360859')}
# {'_id': '19c83fb8-d2ef-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706300712636096170')}
# {'_id': 'd4238958-caf3-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697650943867216141')}
# {'_id': '44f8a0cd-d313-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706906702829385129')}
# {'_id': 'f1d0901e-cad4-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697476637130626818')}
# {'_id': '84654030-dbd5-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693498505184294206')}
# {'_id': 'ff50041a-d336-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698082547247270040')}
# {'_id': 'f3a3b217-dbdb-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693499188347748832')}
# {'_id': '33703ad4-d32c-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698081670408377102')}
# {'_id': 'ad8a6a7d-a41e-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674156736417825161')}
# {'_id': '4e69c38c-c85c-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694624140025014424')}
# {'_id': '813000d6-cab1-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696437904640929602')}
# {'_id': 'e3a2679b-caf2-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697650868248556471')}
# {'_id': '7827a950-d996-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685640290745577697')}
# {'_id': 'f48fe7f7-a4ee-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695054898782439571')}
# {'_id': '825fc170-d2cb-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705954931455594860')}
# {'_id': 'b360d94b-a41c-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674156615413640921')}
# {'_id': '1f794e9f-dc10-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693509010075835790')}
# {'_id': '78540b6c-cae7-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697478081569079033')}
# {'_id': '71d92f1a-a438-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683315280610834418')}
# {'_id': '3f39adb9-ca8c-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695837344739672356')}
# {'_id': 'b9d68651-dc1e-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693927873476482416')}
# {'_id': '85d9163a-a4e6-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694452538975852097')}
# {'_id': 'cd16bd1e-a610-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697474869826183064')}
# {'_id': '249bcbfd-d34a-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698255980155241895')}
# {'_id': 'f5ca7c62-d342-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698255366975781006')}
# {'_id': '8ca91b8d-a513-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695932441034802248')}
# {'_id': '1815cff1-d2a1-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698253210128816555')}
# {'_id': '2b97c996-d98b-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685633296775432018')}
# {'_id': 'b67b805b-ca94-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695837999201853915')}
# {'_id': '95bd0bb1-d31d-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706907907473414244')}
# {'_id': '290ec60b-cad6-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697476731110607316')}
# {'_id': 'e206a445-a5d6-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696870488014677150')}
# {'_id': '481ae2c5-db35-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692297869502906233')}
# {'_id': '3bd8fa4f-db59-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693495919896880189')}
# {'_id': 'a69cb823-cb7c-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696532897610337620')}
# {'_id': '2822ed74-dc27-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693928754213119740')}
# {'_id': '571e3623-d300-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706302457974666775')}
# {'_id': '9499dc1f-cb65-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695324932525361506')}
# {'_id': 'b713713d-d2fa-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706302001937701330')}
# {'_id': 'f1fb867a-d35d-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698348121486002054')}
# {'_id': '3769c539-a432-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685541962049292510')}
# {'_id': '346e4d83-d35d-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698348058605345716')}
# ...
# {'_id': 'c639e79c-a42a-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674157471229724607')}
# {'_id': '4a4046b5-d2e5-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706299929635861992')}
# {'_id': 'bf277044-d305-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706302895095602204')}
# {'_id': '46dce473-a4f2-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695055120664671196')}
# {'_id': '8e6534e0-a656-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697649319522273293')}
# {'_id': '1f45220f-dc19-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693926003523685081')}
# {'_id': '91930fb6-c854-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694623491590511541')}
# {'_id': '153fb57a-d988-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685632936905902390')}
# {'_id': '3ee02e72-a437-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683314900850654532')}
# {'_id': 'c7ccf465-d999-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685640753534381943')}
# {'_id': '3026d171-a655-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697649287238863629')}
# {'_id': 'de15f2d5-db43-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692300526992260372')}
# {'_id': 'f34852cc-d98b-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685633385871688622')}
# {'_id': '91d3d4ba-ca9d-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695838706739421223')}
# {'_id': 'c13bd927-a5ca-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696870070114662016')}
# {'_id': 'c8383d1e-d350-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698256553716254380')}
# {'_id': 'd707fcba-a5ba-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696869469553705157')}
# {'_id': '9450c171-cac9-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872987652747711')}
# {'_id': '54ecc557-a435-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683314337029347147')}
# {'_id': 'ba69ac94-cabd-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872172113660026')}
# {'_id': '654564c1-a54e-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696266966724141603')}
# {'_id': '98a2b794-a4d8-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694451689333252420')}
# {'_id': 'd40c49a8-d286-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698079914238222837')}
# {'_id': '75a9e186-caf2-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697650834367604864')}
# {'_id': '4b034e3f-d340-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698255141499183091')}
# {'_id': 'aacd68fb-d346-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698255683515855429')}
# {'_id': 'd869f19e-d2c8-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705954722875117957')}
# {'_id': '0e516b20-db34-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692297707536549212')}
# {'_id': '2cdf761a-dc1b-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693926214751826713')}
# {'_id': '011450c4-a424-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674157062295744964')}
# {'_id': '33492160-cbaa-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697742834043238625')}
# {'_id': '3adffbed-dc10-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693509021409575195')}
# {'_id': 'ecd1e6ef-d289-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698080147199437925')}
# {'_id': 'a0f9deaa-cbae-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697743239143748939')}
# {'_id': 'df50da4e-d994-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685640066439348636')}
# {'_id': '142808a6-a536-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696265926102284884')}
# {'_id': '0c158cea-d316-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706907286452978773')}
# {'_id': '284f3db0-a502-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695056187122523708')}
# {'_id': 'caaeca21-d2d5-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705955709155016406')}
# {'_id': 'a33e3cd1-c87f-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695229348969952349')}
# {'_id': '4f063431-db35-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692297873497906925')}
# {'_id': '9c4c9856-c854-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694623495123579125')}
# {'_id': 'b180003f-d9bc-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690481056107485613')}
# {'_id': 'c0f58e13-d99c-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1689270925083288262')}
# {'_id': 'c4c1a51b-db4c-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692301783150895623')}
# {'_id': '97ef6394-d345-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698255591257380165')}
# {'_id': '94caad99-d982-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685632202624000166')}
# {'_id': '7c6fabb3-c862-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694624700684274577')}
# {'_id': 'ed89e87d-cbad-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697743180943057499')}
# {'_id': '77158394-cb8d-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697137852856393324')}
# {'_id': '73b231ef-ca94-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695837977919385257')}
# {'_id': '21dd657e-a53b-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696266154143914373')}
# {'_id': '3ba9afb9-cbb2-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697743536043391090')}
# {'_id': '61a83d83-cad9-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697476976310544259')}
# {'_id': '5ef35ecb-a528-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695933537835430946')}
# {'_id': '50368d5b-d33c-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698083003587367596')}
# {'_id': 'fd5ab7c9-a52d-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696265557203894295')}
# {'_id': '066176e6-caad-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696437562398515586')}
# {'_id': '6002606c-cabb-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872000774235260')}
# {'_id': 'a644ab65-d2a1-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698253254928245058')}
# {'_id': '83099ead-a4d4-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694451443251525254')}
# {'_id': 'cec66d3b-a4ca-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694450825194668973')}
# {'_id': '9f38973a-a629-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697648074039380149')}
# {'_id': '580599e3-dbf6-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693503065751661944')}
# {'_id': '0cacfe66-d9ad-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690478648460548002')}
# {'_id': 'ec5118dd-a42f-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685541383049389088')}
# {'_id': '62f0b83a-d2bc-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705953459254745862')}
# {'_id': '1c231e57-caac-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696437489760741071')}
# {'_id': '535a9fe1-a536-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696265939362658647')}
# {'_id': '4f2154c3-c85f-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694624414984420513')}
# {'_id': 'bf35ae38-d9be-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690481355153138459')}
# {'_id': '70f2b1ab-a5f6-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697474039765068888')}
# {'_id': 'fb3d2d56-d2d3-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705955572636349703')}
# {'_id': '08e413c3-d34f-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698256401815479546')}
# {'_id': '8a539db1-a4dd-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694451990073228416')}
# {'_id': '5ec7ce24-d994-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685639995519614274')}
# {'_id': '8bc7913b-a646-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697648890659782661')}
# {'_id': '5b7dad65-a42b-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674157504495255805')}
# {'_id': 'c1944c00-db51-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693494968848342262')}
# {'_id': 'e8b4a47d-cac7-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696872868592924358')}
# {'_id': '6588627f-d31c-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706907809353818048')}
# {'_id': 'ca0c0273-a53a-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696266141384163009')}
# {'_id': '201c3feb-a5d7-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696870495653801839')}
# {'_id': '85c2a31b-cada-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697477065849688024')}
# {'_id': '149dbe15-d2e9-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706300232978136094')}
# {'_id': '073c8fbe-d33b-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698082890707460016')}
# {'_id': 'f501b788-dbd5-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693498555476027757')}
# {'_id': '455f4ece-d9cd-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690483514904149781')}
# {'_id': 'eff776ec-cad0-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696873500973626108')}
# {'_id': 'b46f15d7-cb99-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697139059716515265')}
# {'_id': '236520fb-d33f-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698255043656751578')}
# {'_id': '481f4a5f-a434-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1683314029860692228')}
# {'_id': '1504af9a-dc17-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693509729965642303')}
# {'_id': 'f116149c-d35a-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698347866685922321')}
# {'_id': '1633dca1-a4cb-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694450844512990293')}
# {'_id': '855345a7-caa7-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696437136819588214')}
# {'_id': 'e7d97d66-db1e-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1692284543074131765')}
# {'_id': 'be968296-dc0e-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693508863391942274')}
# {'_id': '999e23b2-d27e-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698079285759615550')}
# {'_id': '4d1a9016-c87c-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695229039828038576')}
# {'_id': 'cce39c07-d280-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698079456418655923')}
# {'_id': '6e0298eb-cbb1-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697743468983228925')}
# {'_id': '8db94642-c85d-11ee-a7fc-dd032dba19e8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694624254484408661')}
# {'_id': '91a86467-a40d-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1674155660175611770')}
# {'_id': '27058e95-a42f-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685541314188719942')}
# {'_id': '9da1c98b-d2b9-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705953247535503934')}
# {'_id': '3f5355f0-d34d-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698256246579600270')}
# {'_id': '2d224d07-cad0-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696873445586598002')}
# {'_id': '53006d30-a601-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1697474391466188873')}
# {'_id': '037bea12-d2a2-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698253284988571130')}
# {'_id': '620e166e-a4d6-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694451557853384627')}
# {'_id': 'e2e1658a-d999-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1685640767917806929')}
# {'_id': '3ff3e94c-d2b9-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705953219235613413')}
# {'_id': '5339e324-d2f2-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706300971995126514')}
# {'_id': '74193a9e-d295-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698252270126616705')}
# {'_id': 'ef1d4344-db58-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1693495879606960403')}
# {'_id': '676b5273-cb54-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694719093869530301')}
# {'_id': 'd3aeb402-ca98-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1695838308759878656')}
# {'_id': '95b0d444-d326-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698081226690298497')}
# {'_id': '9d7c084c-a4ce-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1694451078801589955')}
# {'_id': '06d996c5-d2c5-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1705954423395215429')}
# {'_id': '500279de-d273-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698078480197640339')}
# {'_id': 'bdbf7e75-d323-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706908415612999438')}
# {'_id': '26372719-d2df-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706299433036097968')}
# {'_id': '7c6eabf5-d9b4-11ee-a158-97f8443fd730', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1690479678260593745')}
# {'_id': 'd11b460f-d32b-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1698081642807421984')}
# {'_id': '57a02175-cab2-11ee-909c-e1dc60cf66f9', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696437970257368585')}
# {'_id': 'ecdee867-a5de-11ee-88ec-eb6a8d5269b4', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1696870761334076041')}
# {'_id': '1e6c70f5-d2f4-11ee-b437-336917683bb8', 'topic': '/apollo/canbus/chassis', 'time': Decimal('1706301117763451697')}
# done querying for chassis data
# Saved chassis data at ../data/chassis/1bbbfbae-c839-11ee-a7fc-dd032dba19e8.csv
# (8231, 31)

# %%
if not os.path.exists(f"../data/metadata"):
    os.makedirs(f"../data/metadata")

if queryMeta:

    #query arguments for metadata data
    keywords = dict(
        IndexName='groupMetadataID-index',
        KeyConditionExpression=Key("groupMetadataID").eq(gmID),
        ProjectionExpression = "groupMetadataID, #o.Weather, #o.#m, #o.Notes",
        Limit=1500,
        ExpressionAttributeNames={"#o":"other","#m":"Map"},
    )


    #run query for metadata data and create dataframe
    res = table.query(**keywords)
    df_meta = pd.DataFrame.from_dict(
        pd.json_normalize(res['Items']),orient='columns').drop_duplicates()

    df_meta.to_csv(f"../data/metadata/{gmID}.csv")
    print(f"Saved metadata data at ../data/metadata/{gmID}.csv")


else:
    df_meta = pd.read_csv(f"../data/metadata/{gmID}.csv")
    print("Loaded metadata data")
            
        
print(df_meta.shape)
# Out:
# Saved metadata data at ../data/metadata/1bbbfbae-c839-11ee-a7fc-dd032dba19e8.csv
# (1, 1)

# %%
# read the timeSorted csv
pts = df_chassis.copy()
pts = pts.sort_values('time')
# reduce df to only time and drivingMode
pts = pts[["time", "drivingMode"]]
# function to tell us what state transition it is


def getState(old, new):
    if old == "COMPLETE_AUTO_DRIVE" and new == "COMPLETE_MANUAL":
        return "A->M"
    elif old == "COMPLETE_AUTO_DRIVE" and new == "EMERGENCY_MODE":
        return "A->M"
    elif old == "COMPLETE_MANUAL" and new == "COMPLETE_AUTO_DRIVE":
        return "M->A"
    elif old == "EMERGENCY_MODE" and new == "COMPLETE_AUTO_DRIVE":
        return "M->A"
    else:
        return "NONE"


# we shift the drivingMode column down by 1
pts["shift"] = pts["drivingMode"].shift()
# create transition field
pts['transition'] = (pts["drivingMode"] != pts["shift"])
# set Transition type to NONE for all
pts['transitionType'] = "NONE"
# Set first transition to False, since it was auto True
pts.loc[0, 'transition'] = False
# print(pts['transition'])
# Show counts for transitions
print(pts['transition'].value_counts())
# iterate over all rows and find the ones where transition is true. Then we compare shift and dM to see what
# transition Type we have.
for index, row in pts.iterrows():
    if pts['transition'][index] == True:
        old = pts['shift'][index]
        new = pts['drivingMode'][index]
        pts.loc[index, "transitionType"] = getState(old, new)
print(pts['transitionType'].value_counts())
pts = pts[['time', 'drivingMode', 'transition', 'transitionType']]
pts = pts.sort_values('time')
pts['time'] = pts['time'].astype(float)
pts['time'] = pts['time'].astype('datetime64[ns]')
pts['time'] = pts['time'].astype('datetime64[s]')
pts[['time']]

# show(pts)
# Out:
# transition
# False    8227
# True        4
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7418/3040278865.py in ?()
#      32 print(pts['transition'].value_counts())
#      33 # iterate over all rows and find the ones where transition is true. Then we compare shift and dM to see what
#      34 # transition Type we have.
#      35 for index, row in pts.iterrows():
# ---> 36     if pts['transition'][index] == True:
#      37         old = pts['shift'][index]
#      38         new = pts['drivingMode'][index]
#      39         pts.loc[index, "transitionType"] = getState(old, new)
#
# ~/do-env/lib/python3.10/site-packages/pandas/core/generic.py in ?(self)
#    1574     @final
#    1575     def __nonzero__(self) -> NoReturn:
# -> 1576         raise ValueError(
#    1577             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1578             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1579         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#Convert and sort the time column
bestPose = df_pose.copy()
bestPose = bestPose.sort_values('time')
bestPose['time'] = bestPose['time'].astype(float)
bestPose['time'] = bestPose['time'].astype('datetime64[ns]')
bestPose['time'] = bestPose['time'].astype('datetime64[s]')

#merging best_pose and chassis dataframes
merged_df = pd.merge(pts, bestPose, on='time')

# %% [markdown]
# Satellite and Standard Deviation and Work

# %%
#Finding the min and max number of satellites in the view
print(f"NumStatsTracked Max: {bestPose['numSatsTracked'].max()}")
print(f"NumStatsTracked Min: {bestPose['numSatsTracked'].min()}")

# %%
#Find the min and max number of satellites being used
print(f"NumStatsInSolution Max: {bestPose['numSatsInSolution'].max()}")
print(f"NumStatsInSolution Min: {bestPose['numSatsInSolution'].min()}")

# %%
#Find the max and min number of 4 satellites in a constellation
print(f"NumStatsMulti Max: {bestPose['numSatsMulti'].max()}")
print(f"NumStatsMulti Min: {bestPose['numSatsMulti'].min()}")

# %%
#Determine radius for latitude and longitude 
#x is longitudeStdDev and y is lattitudeStdDev 
#radius is the hypotenuse to determine the distance the points are off from the actual
for index, row in merged_df.iterrows():
    merged_df.loc[index, "radius"] = np.sqrt((merged_df.loc[index,"longitudeStdDev"] ** 2) + (merged_df.loc[index,"latitudeStdDev"] ** 2))

# %%
#Mapping driving mode to determine relationship between std dev, numberSatsInSolution and driving mode
fig = px.scatter_mapbox(merged_df, lat="latitude", lon="longitude", hover_name="drivingMode", hover_data=["time","drivingMode", "numSatsInSolution", "solStatus"], 
                        color="drivingMode",
                        size="radius", size_max=16,
                        zoom=12, height=1000, mapbox_style="open-street-map",
                        color_discrete_map={
                             "COMPLETE_MANUAL": "#601A4A",
                             "COMPLETE_AUTO_DRIVE": "#63ACBE",
                             "EMERGENCY_MODE": "#EE442F",
                         })

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
#Scatter plot to show relationship between driving mode and number of satellites
fig = px.scatter(merged_df, x="drivingMode", y="numSatsInSolution")
fig.show()

# %%
#Showing relationship between the satellite status and the number of satellites. 
fig = px.scatter(merged_df, x="solStatus", y="numSatsInSolution")
fig.show()

# %%
#Showing relationship between the satellite status and the number of satellites. 
fig = px.scatter(merged_df, x="solType", y="numSatsInSolution")
fig.show()
