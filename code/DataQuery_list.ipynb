# %% [markdown]
# # Data Query (specific groupMetadataID)

# %% [markdown]
# #### **ONLY RUN IF MASSIVE AMOUNTS OF DATA IS YOUR GOAL**
#
# Runs a query for the chosen groupMetadataID, retrieving chassis and best_pose data.
# Then runs a query for metadata.

# %%
import plotly.express as px
import pandas as pd
import numpy as np
import os

# Import plotly.express to utilize map

# %% [markdown]
# ### Import your groupMetadataIDs below and choose to query data or not

# %%
# select a groupMetadataID
gmIDs = pd.read_csv("gmIDs.csv")["groupMetadataID"]
print(len(gmIDs))

# set to False if data is stored as .csv file.
# otherwise, set to True
queryPose = True
queryChassis = True
queryMeta = True
# Out:
# 59

# %%
from boto3.dynamodb.conditions import Key, Attr
import boto3

if queryPose or queryChassis or queryMeta:
    # Get the service resource
    dynamodb = boto3.resource('dynamodb')
    # Instantiate a table resource object
    table = dynamodb.Table('ads_passenger_processed')
    table_meta = dynamodb.Table('ads_passenger_processed_metadata')

# %% [markdown]
# ### Query and save Best_pose data

# %%
if queryPose:
    if not os.path.exists(f"./data/best_pose"):
        os.makedirs(f"./data/best_pose")

    for gmID in gmIDs:
        if not os.path.exists(f"./data/best_pose/{gmID}.csv"):
            print(f"querying best_pose for {gmID}")

        else:
            print(f"skipping {gmID}, data already exists")
            continue

        # query arguments for best_pose data
        keywords = dict(
            IndexName='topic-index',
            KeyConditionExpression=Key('topic').eq(
                '/apollo/sensor/gnss/best_pose'),
            ProjectionExpression="groupMetadataID, #t, solStatus, solType, latitudeStdDev, longitudeStdDev, numSatsTracked, numSatsMulti, numSatsInSolution, differentialAge, solutionAge, latitude, longitude",
            Limit=1500,
            ExpressionAttributeNames={'#t': 'time'},
            FilterExpression=Key('groupMetadataID').eq(f'{gmID}')

        )

        # run initial query and coerce results into a dataframe
        res = table.query(**keywords)
        df_pose = pd.DataFrame.from_dict(
            pd.json_normalize(res['Items']), orient='columns')

        done = False
        leek = res["LastEvaluatedKey"]

        while not done:
            try:
                leek = res["LastEvaluatedKey"]
                keywords["ExclusiveStartKey"] = leek
                res = table.query(**keywords)
                tmpDF = pd.DataFrame.from_dict(
                    pd.json_normalize(res['Items']), orient='columns')
                df_pose = pd.concat([df_pose, tmpDF])
            except KeyError:
                print("Done querying best_pose data")
                done = True

        df_pose.to_csv(f"./data/best_pose/{gmID}.csv", index=False)
        print(f"Saved best_pose data at ./data/best_pose/{gmID}.csv\n")

print("\nfinished")
# Out:
# querying best_pose for 2bc6ebb8-a529-11ee-88ec-eb6a8d5269b4
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/2bc6ebb8-a529-11ee-88ec-eb6a8d5269b4.csv
#
# querying best_pose for 8fa6fe80-c869-11ee-a7fc-dd032dba19e8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/8fa6fe80-c869-11ee-a7fc-dd032dba19e8.csv
#
# querying best_pose for 837fc882-cb5a-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/837fc882-cb5a-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 3d8020aa-cb7f-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/3d8020aa-cb7f-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 559495ca-d270-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/559495ca-d270-11ee-b437-336917683bb8.csv
#
# querying best_pose for 47561998-d9c3-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/47561998-d9c3-11ee-a158-97f8443fd730.csv
#
# querying best_pose for 25641404-cb66-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/25641404-cb66-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 286c70cc-d2f7-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/286c70cc-d2f7-11ee-b437-336917683bb8.csv
#
# querying best_pose for c9c6856c-d33c-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/c9c6856c-d33c-11ee-b437-336917683bb8.csv
#
# querying best_pose for 7f09f6c6-a5b0-11ee-88ec-eb6a8d5269b4
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/7f09f6c6-a5b0-11ee-88ec-eb6a8d5269b4.csv
#
# querying best_pose for d12cd1c4-caec-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/d12cd1c4-caec-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 3c415ade-d353-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/3c415ade-d353-11ee-b437-336917683bb8.csv
#
# querying best_pose for 3a2a78cc-db21-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/3a2a78cc-db21-11ee-a158-97f8443fd730.csv
#
# querying best_pose for e6d7d384-db40-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/e6d7d384-db40-11ee-a158-97f8443fd730.csv
#
# querying best_pose for 3a116996-93a9-11ee-956e-9da2d070324c
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/3a116996-93a9-11ee-956e-9da2d070324c.csv
#
# querying best_pose for 8437f77a-cab7-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/8437f77a-cab7-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 19b7ebd0-d9b7-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/19b7ebd0-d9b7-11ee-a158-97f8443fd730.csv
#
# querying best_pose for 853ef120-cad3-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/853ef120-cad3-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 64737d98-d312-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/64737d98-d312-11ee-b437-336917683bb8.csv
#
# querying best_pose for 5976b77a-a504-11ee-88ec-eb6a8d5269b4
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/5976b77a-a504-11ee-88ec-eb6a8d5269b4.csv
#
# querying best_pose for baf0e4be-bede-11ee-835b-599066b5eb60
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/baf0e4be-bede-11ee-835b-599066b5eb60.csv
#
# querying best_pose for 76683d3c-db18-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/76683d3c-db18-11ee-a158-97f8443fd730.csv
#
# querying best_pose for f671c05c-a5e4-11ee-88ec-eb6a8d5269b4
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/f671c05c-a5e4-11ee-88ec-eb6a8d5269b4.csv
#
# querying best_pose for c338788a-d324-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/c338788a-d324-11ee-b437-336917683bb8.csv
#
# querying best_pose for 9830d896-d2dc-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/9830d896-d2dc-11ee-b437-336917683bb8.csv
#
# querying best_pose for 787d9684-d2c2-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/787d9684-d2c2-11ee-b437-336917683bb8.csv
#
# querying best_pose for 6d2ea45a-c839-11ee-a7fc-dd032dba19e8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/6d2ea45a-c839-11ee-a7fc-dd032dba19e8.csv
#
# querying best_pose for b31aca98-cb95-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/b31aca98-cb95-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 7fb7b9c0-c881-11ee-a7fc-dd032dba19e8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/7fb7b9c0-c881-11ee-a7fc-dd032dba19e8.csv
#
# querying best_pose for aa86a660-dc05-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/aa86a660-dc05-11ee-a158-97f8443fd730.csv
#
# querying best_pose for a253145a-d2a6-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/a253145a-d2a6-11ee-b437-336917683bb8.csv
#
# querying best_pose for feaf2ba8-d28d-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/feaf2ba8-d28d-11ee-b437-336917683bb8.csv
#
# querying best_pose for e2079a78-dc1d-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/e2079a78-dc1d-11ee-a158-97f8443fd730.csv
#
# querying best_pose for 58263e34-a45c-11ee-88ec-eb6a8d5269b4
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/58263e34-a45c-11ee-88ec-eb6a8d5269b4.csv
#
# querying best_pose for 2837eb9c-9542-11ee-956e-9da2d070324c
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/2837eb9c-9542-11ee-956e-9da2d070324c.csv
#
# querying best_pose for 69ab88ec-dc17-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/69ab88ec-dc17-11ee-a158-97f8443fd730.csv
#
# querying best_pose for dc39aa14-db32-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/dc39aa14-db32-11ee-a158-97f8443fd730.csv
#
# querying best_pose for 072ef896-cbac-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/072ef896-cbac-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 6af236d6-d98f-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/6af236d6-d98f-11ee-a158-97f8443fd730.csv
#
# querying best_pose for 8c57e8ac-dbec-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/8c57e8ac-dbec-11ee-a158-97f8443fd730.csv
#
# querying best_pose for 8b0593cc-cb4e-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/8b0593cc-cb4e-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for c0624e24-d9aa-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/c0624e24-d9aa-11ee-a158-97f8443fd730.csv
#
# querying best_pose for 51ef6da6-ca9f-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/51ef6da6-ca9f-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 86841630-d9d0-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/86841630-d9d0-11ee-a158-97f8443fd730.csv
#
# querying best_pose for c335d84c-a45c-11ee-88ec-eb6a8d5269b4
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/c335d84c-a45c-11ee-88ec-eb6a8d5269b4.csv
#
# querying best_pose for ba6e1072-9524-11ee-956e-9da2d070324c
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/ba6e1072-9524-11ee-956e-9da2d070324c.csv
#
# querying best_pose for a6539bd2-cb72-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/a6539bd2-cb72-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 154fab12-a43f-11ee-88ec-eb6a8d5269b4
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/154fab12-a43f-11ee-88ec-eb6a8d5269b4.csv
#
# querying best_pose for 271fee10-cb8b-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/271fee10-cb8b-11ee-909c-e1dc60cf66f9.csv
#
# querying best_pose for 68c289fa-dbd4-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/68c289fa-dbd4-11ee-a158-97f8443fd730.csv
#
# querying best_pose for 88b0613a-d35d-11ee-b437-336917683bb8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/88b0613a-d35d-11ee-b437-336917683bb8.csv
#
# querying best_pose for f9d62032-db2a-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/f9d62032-db2a-11ee-a158-97f8443fd730.csv
#
# querying best_pose for 90101c36-a621-11ee-88ec-eb6a8d5269b4
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/90101c36-a621-11ee-88ec-eb6a8d5269b4.csv
#
# querying best_pose for 39ba7438-d0d5-11ee-9435-f7e542e2436c
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/39ba7438-d0d5-11ee-9435-f7e542e2436c.csv
#
# querying best_pose for 06cbdbc0-db4d-11ee-a158-97f8443fd730
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/06cbdbc0-db4d-11ee-a158-97f8443fd730.csv
#
# querying best_pose for f6ac3c82-a445-11ee-88ec-eb6a8d5269b4
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/f6ac3c82-a445-11ee-88ec-eb6a8d5269b4.csv
#
# querying best_pose for da853e0c-a10f-11ee-981c-d126ddbe9afa
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/da853e0c-a10f-11ee-981c-d126ddbe9afa.csv
#
# querying best_pose for 1bbbfbae-c839-11ee-a7fc-dd032dba19e8
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/1bbbfbae-c839-11ee-a7fc-dd032dba19e8.csv
#
# querying best_pose for ed352100-cba0-11ee-909c-e1dc60cf66f9
# Done querying best_pose data
# Saved best_pose data at ./data/best_pose/ed352100-cba0-11ee-909c-e1dc60cf66f9.csv
#
#
# finished

# %% [markdown]
# ### Query and save Chassis data

# %% [markdown]
# Warning: This query can take awhile. frequently over 5 minutes

# %%
if queryChassis:
    if not os.path.exists(f"./data/chassis"):
        os.makedirs(f"./data/chassis")

    for gmID in gmIDs:
        if not os.path.exists(f"./data/chassis/{gmID}.csv"):
            print(f"querying chassis for {gmID}")

        else:
            print(f"skipping {gmID}, data already exists")
            continue

        keywords = dict(
            IndexName='topic-index',
            KeyConditionExpression=Key('groupMetadataID').eq(gmID),
            Limit=2000,
            FilterExpression=Key('topic').eq(
                '/apollo/canbus/chassis')
        )

        res = table.query(**keywords)
        df_chassis = pd.DataFrame.from_dict(
            pd.json_normalize(res['Items']), orient='columns')

        done = False
        leek = res["LastEvaluatedKey"]

        while not done:
            try:
                leek = res["LastEvaluatedKey"]
                keywords["ExclusiveStartKey"] = leek
                res = table.query(**keywords)
                tmpDF = pd.DataFrame.from_dict(
                    pd.json_normalize(res['Items']), orient='columns')
                df_chassis = pd.concat([df_chassis, tmpDF])
                # print(leek)

            except KeyError:
                print(f"done querying for chassis data")
                done = True

        df_chassis.to_csv(f"./data/chassis/{gmID}.csv", index=False)
        print(f"Saved chassis data at ./data/chassis/{gmID}.csv")
print("\nfinished")
# Out:
# skipping 2bc6ebb8-a529-11ee-88ec-eb6a8d5269b4, data already exists
# skipping 8fa6fe80-c869-11ee-a7fc-dd032dba19e8, data already exists
# skipping 837fc882-cb5a-11ee-909c-e1dc60cf66f9, data already exists
# skipping 3d8020aa-cb7f-11ee-909c-e1dc60cf66f9, data already exists
# skipping 559495ca-d270-11ee-b437-336917683bb8, data already exists
# skipping 47561998-d9c3-11ee-a158-97f8443fd730, data already exists
# skipping 25641404-cb66-11ee-909c-e1dc60cf66f9, data already exists
# skipping 286c70cc-d2f7-11ee-b437-336917683bb8, data already exists
# skipping c9c6856c-d33c-11ee-b437-336917683bb8, data already exists
# skipping 7f09f6c6-a5b0-11ee-88ec-eb6a8d5269b4, data already exists
# skipping d12cd1c4-caec-11ee-909c-e1dc60cf66f9, data already exists
# skipping 3c415ade-d353-11ee-b437-336917683bb8, data already exists
# skipping 3a2a78cc-db21-11ee-a158-97f8443fd730, data already exists
# querying chassis for e6d7d384-db40-11ee-a158-97f8443fd730
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 32
#      30 leek = res["LastEvaluatedKey"]
#      31 keywords["ExclusiveStartKey"] = leek
# ---> 32 res = table.query(**keywords)
#      33 tmpDF = pd.DataFrame.from_dict(
#      34     pd.json_normalize(res['Items']), orient='columns')
#      35 df_chassis = pd.concat([df_chassis, tmpDF])
#
# File ~/do-env/lib/python3.10/site-packages/boto3/resources/factory.py:581, in ResourceFactory._create_action.<locals>.do_action(self, *args, **kwargs)
#     580 def do_action(self, *args, **kwargs):
# --> 581     response = action(self, *args, **kwargs)
#     583     if hasattr(self, 'load'):
#     584         # Clear cached data. It will be reloaded the next
#     585         # time that an attribute is accessed.
#     586         # TODO: Make this configurable in the future?
#     587         self.meta.data = None
#
# File ~/do-env/lib/python3.10/site-packages/boto3/resources/action.py:88, in ServiceAction.__call__(self, parent, *args, **kwargs)
#      79 params.update(kwargs)
#      81 logger.debug(
#      82     'Calling %s:%s with %r',
#      83     parent.meta.service_name,
#      84     operation_name,
#      85     params,
#      86 )
# ---> 88 response = getattr(parent.meta.client, operation_name)(*args, **params)
#      90 logger.debug('Response: %r', response)
#      92 return self._response_handler(parent, params, response)
#
# File ~/do-env/lib/python3.10/site-packages/botocore/client.py:553, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     549     raise TypeError(
#     550         f"{py_operation_name}() only accepts keyword arguments."
#     551     )
#     552 # The "self" in this scope is referring to the BaseClient.
# --> 553 return self._make_api_call(operation_name, kwargs)
#
# File ~/do-env/lib/python3.10/site-packages/botocore/client.py:989, in BaseClient._make_api_call(self, operation_name, api_params)
#     985     maybe_compress_request(
#     986         self.meta.config, request_dict, operation_model
#     987     )
#     988     apply_request_checksum(request_dict)
# --> 989     http, parsed_response = self._make_request(
#     990         operation_model, request_dict, request_context
#     991     )
#     993 self.meta.events.emit(
#     994     'after-call.{service_id}.{operation_name}'.format(
#     995         service_id=service_id, operation_name=operation_name
#    (...)
#    1000     context=request_context,
#    1001 )
#    1003 if http.status_code >= 300:
#
# File ~/do-env/lib/python3.10/site-packages/botocore/client.py:1015, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1013 def _make_request(self, operation_model, request_dict, request_context):
#    1014     try:
# -> 1015         return self._endpoint.make_request(operation_model, request_dict)
#    1016     except Exception as e:
#    1017         self.meta.events.emit(
#    1018             'after-call-error.{service_id}.{operation_name}'.format(
#    1019                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#    1023             context=request_context,
#    1024         )
#
# File ~/do-env/lib/python3.10/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File ~/do-env/lib/python3.10/site-packages/botocore/endpoint.py:202, in Endpoint._send_request(self, request_dict, operation_model)
#     198 request = self.create_request(request_dict, operation_model)
#     199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
# --> 202 while self._needs_retry(
#     203     attempts,
#     204     operation_model,
#     205     request_dict,
#     206     success_response,
#     207     exception,
#     208 ):
#     209     attempts += 1
#     210     self._update_retries_context(context, attempts, success_response)
#
# File ~/do-env/lib/python3.10/site-packages/botocore/endpoint.py:373, in Endpoint._needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#     366 else:
#     367     # Request needs to be retried, and we need to sleep
#     368     # for the specified number of times.
#     369     logger.debug(
#     370         "Response received to retry, sleeping for %s seconds",
#     371         handler_response,
#     372     )
# --> 373     time.sleep(handler_response)
#     374     return True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Query and save Metadata

# %%
if queryMeta:

    if not os.path.exists(f"./data/metadata"):
        os.makedirs(f"./data/metadata")

    for gmID in gmIDs:
        if not os.path.exists(f"./data/metadata/{gmID}.csv"):
            print(f"querying metadata for {gmID}")

        else:
            print(f"skipping {gmID}, data already exists")
            continue

        res = table_meta.query(
            IndexName='groupMetadataID-index',
            KeyConditionExpression=Key("groupMetadataID").eq(gmID),
            # ProjectionExpression="groupMetadataID, #o.Weather, #o.#m, #o.Notes",
            Limit=2000,
            # ExpressionAttributeNames={"#o": "other", "#m": "Map"},
        )

        df_meta = pd.DataFrame.from_dict(
            pd.json_normalize(res['Items']), orient='columns')

        print(df_meta.shape)

        df_meta.to_csv(f"./data/metadata/{gmID}.csv", index=False)
        print(f"Saved metadata data at ./data/metadata/{gmID}.csv")
# Out:
# querying metadata for 2bc6ebb8-a529-11ee-88ec-eb6a8d5269b4
# (6, 17)
# Saved metadata data at ./data/metadata/2bc6ebb8-a529-11ee-88ec-eb6a8d5269b4.csv
# querying metadata for 8fa6fe80-c869-11ee-a7fc-dd032dba19e8
# (10, 17)
# Saved metadata data at ./data/metadata/8fa6fe80-c869-11ee-a7fc-dd032dba19e8.csv
# querying metadata for 837fc882-cb5a-11ee-909c-e1dc60cf66f9
# (16, 17)
# Saved metadata data at ./data/metadata/837fc882-cb5a-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 3d8020aa-cb7f-11ee-909c-e1dc60cf66f9
# (19, 17)
# Saved metadata data at ./data/metadata/3d8020aa-cb7f-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 559495ca-d270-11ee-b437-336917683bb8
# (11, 17)
# Saved metadata data at ./data/metadata/559495ca-d270-11ee-b437-336917683bb8.csv
# querying metadata for 47561998-d9c3-11ee-a158-97f8443fd730
# (37, 22)
# Saved metadata data at ./data/metadata/47561998-d9c3-11ee-a158-97f8443fd730.csv
# querying metadata for 25641404-cb66-11ee-909c-e1dc60cf66f9
# (17, 17)
# Saved metadata data at ./data/metadata/25641404-cb66-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 286c70cc-d2f7-11ee-b437-336917683bb8
# (9, 17)
# Saved metadata data at ./data/metadata/286c70cc-d2f7-11ee-b437-336917683bb8.csv
# querying metadata for c9c6856c-d33c-11ee-b437-336917683bb8
# (9, 17)
# Saved metadata data at ./data/metadata/c9c6856c-d33c-11ee-b437-336917683bb8.csv
# querying metadata for 7f09f6c6-a5b0-11ee-88ec-eb6a8d5269b4
# (11, 17)
# Saved metadata data at ./data/metadata/7f09f6c6-a5b0-11ee-88ec-eb6a8d5269b4.csv
# querying metadata for d12cd1c4-caec-11ee-909c-e1dc60cf66f9
# (8, 17)
# Saved metadata data at ./data/metadata/d12cd1c4-caec-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 3c415ade-d353-11ee-b437-336917683bb8
# (20, 17)
# Saved metadata data at ./data/metadata/3c415ade-d353-11ee-b437-336917683bb8.csv
# querying metadata for 3a2a78cc-db21-11ee-a158-97f8443fd730
# (36, 22)
# Saved metadata data at ./data/metadata/3a2a78cc-db21-11ee-a158-97f8443fd730.csv
# querying metadata for e6d7d384-db40-11ee-a158-97f8443fd730
# (34, 22)
# Saved metadata data at ./data/metadata/e6d7d384-db40-11ee-a158-97f8443fd730.csv
# querying metadata for 3a116996-93a9-11ee-956e-9da2d070324c
# (6, 16)
# Saved metadata data at ./data/metadata/3a116996-93a9-11ee-956e-9da2d070324c.csv
# querying metadata for 8437f77a-cab7-11ee-909c-e1dc60cf66f9
# (7, 17)
# Saved metadata data at ./data/metadata/8437f77a-cab7-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 19b7ebd0-d9b7-11ee-a158-97f8443fd730
# (39, 22)
# Saved metadata data at ./data/metadata/19b7ebd0-d9b7-11ee-a158-97f8443fd730.csv
# querying metadata for 853ef120-cad3-11ee-909c-e1dc60cf66f9
# (10, 17)
# Saved metadata data at ./data/metadata/853ef120-cad3-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 64737d98-d312-11ee-b437-336917683bb8
# (12, 17)
# Saved metadata data at ./data/metadata/64737d98-d312-11ee-b437-336917683bb8.csv
# querying metadata for 5976b77a-a504-11ee-88ec-eb6a8d5269b4
# (10, 17)
# Saved metadata data at ./data/metadata/5976b77a-a504-11ee-88ec-eb6a8d5269b4.csv
# querying metadata for baf0e4be-bede-11ee-835b-599066b5eb60
# (38, 21)
# Saved metadata data at ./data/metadata/baf0e4be-bede-11ee-835b-599066b5eb60.csv
# querying metadata for 76683d3c-db18-11ee-a158-97f8443fd730
# (32, 22)
# Saved metadata data at ./data/metadata/76683d3c-db18-11ee-a158-97f8443fd730.csv
# querying metadata for f671c05c-a5e4-11ee-88ec-eb6a8d5269b4
# (10, 17)
# Saved metadata data at ./data/metadata/f671c05c-a5e4-11ee-88ec-eb6a8d5269b4.csv
# querying metadata for c338788a-d324-11ee-b437-336917683bb8
# (6, 17)
# Saved metadata data at ./data/metadata/c338788a-d324-11ee-b437-336917683bb8.csv
# querying metadata for 9830d896-d2dc-11ee-b437-336917683bb8
# (7, 17)
# Saved metadata data at ./data/metadata/9830d896-d2dc-11ee-b437-336917683bb8.csv
# querying metadata for 787d9684-d2c2-11ee-b437-336917683bb8
# (9, 17)
# Saved metadata data at ./data/metadata/787d9684-d2c2-11ee-b437-336917683bb8.csv
# querying metadata for 6d2ea45a-c839-11ee-a7fc-dd032dba19e8
# (7, 17)
# Saved metadata data at ./data/metadata/6d2ea45a-c839-11ee-a7fc-dd032dba19e8.csv
# querying metadata for b31aca98-cb95-11ee-909c-e1dc60cf66f9
# (19, 17)
# Saved metadata data at ./data/metadata/b31aca98-cb95-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 7fb7b9c0-c881-11ee-a7fc-dd032dba19e8
# (7, 17)
# Saved metadata data at ./data/metadata/7fb7b9c0-c881-11ee-a7fc-dd032dba19e8.csv
# querying metadata for aa86a660-dc05-11ee-a158-97f8443fd730
# (37, 22)
# Saved metadata data at ./data/metadata/aa86a660-dc05-11ee-a158-97f8443fd730.csv
# querying metadata for a253145a-d2a6-11ee-b437-336917683bb8
# (13, 17)
# Saved metadata data at ./data/metadata/a253145a-d2a6-11ee-b437-336917683bb8.csv
# querying metadata for feaf2ba8-d28d-11ee-b437-336917683bb8
# (10, 17)
# Saved metadata data at ./data/metadata/feaf2ba8-d28d-11ee-b437-336917683bb8.csv
# querying metadata for e2079a78-dc1d-11ee-a158-97f8443fd730
# (32, 22)
# Saved metadata data at ./data/metadata/e2079a78-dc1d-11ee-a158-97f8443fd730.csv
# querying metadata for 58263e34-a45c-11ee-88ec-eb6a8d5269b4
# (8, 17)
# Saved metadata data at ./data/metadata/58263e34-a45c-11ee-88ec-eb6a8d5269b4.csv
# querying metadata for 2837eb9c-9542-11ee-956e-9da2d070324c
# (28, 16)
# Saved metadata data at ./data/metadata/2837eb9c-9542-11ee-956e-9da2d070324c.csv
# querying metadata for 69ab88ec-dc17-11ee-a158-97f8443fd730
# (14, 22)
# Saved metadata data at ./data/metadata/69ab88ec-dc17-11ee-a158-97f8443fd730.csv
# querying metadata for dc39aa14-db32-11ee-a158-97f8443fd730
# (37, 22)
# Saved metadata data at ./data/metadata/dc39aa14-db32-11ee-a158-97f8443fd730.csv
# querying metadata for 072ef896-cbac-11ee-909c-e1dc60cf66f9
# (18, 17)
# Saved metadata data at ./data/metadata/072ef896-cbac-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 6af236d6-d98f-11ee-a158-97f8443fd730
# (38, 21)
# Saved metadata data at ./data/metadata/6af236d6-d98f-11ee-a158-97f8443fd730.csv
# querying metadata for 8c57e8ac-dbec-11ee-a158-97f8443fd730
# (34, 22)
# Saved metadata data at ./data/metadata/8c57e8ac-dbec-11ee-a158-97f8443fd730.csv
# querying metadata for 8b0593cc-cb4e-11ee-909c-e1dc60cf66f9
# (16, 17)
# Saved metadata data at ./data/metadata/8b0593cc-cb4e-11ee-909c-e1dc60cf66f9.csv
# querying metadata for c0624e24-d9aa-11ee-a158-97f8443fd730
# (39, 22)
# Saved metadata data at ./data/metadata/c0624e24-d9aa-11ee-a158-97f8443fd730.csv
# querying metadata for 51ef6da6-ca9f-11ee-909c-e1dc60cf66f9
# (12, 17)
# Saved metadata data at ./data/metadata/51ef6da6-ca9f-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 86841630-d9d0-11ee-a158-97f8443fd730
# (23, 22)
# Saved metadata data at ./data/metadata/86841630-d9d0-11ee-a158-97f8443fd730.csv
# querying metadata for c335d84c-a45c-11ee-88ec-eb6a8d5269b4
# (9, 17)
# Saved metadata data at ./data/metadata/c335d84c-a45c-11ee-88ec-eb6a8d5269b4.csv
# querying metadata for ba6e1072-9524-11ee-956e-9da2d070324c
# (12, 17)
# Saved metadata data at ./data/metadata/ba6e1072-9524-11ee-956e-9da2d070324c.csv
# querying metadata for a6539bd2-cb72-11ee-909c-e1dc60cf66f9
# (14, 17)
# Saved metadata data at ./data/metadata/a6539bd2-cb72-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 154fab12-a43f-11ee-88ec-eb6a8d5269b4
# (28, 17)
# Saved metadata data at ./data/metadata/154fab12-a43f-11ee-88ec-eb6a8d5269b4.csv
# querying metadata for 271fee10-cb8b-11ee-909c-e1dc60cf66f9
# (21, 17)
# Saved metadata data at ./data/metadata/271fee10-cb8b-11ee-909c-e1dc60cf66f9.csv
# querying metadata for 68c289fa-dbd4-11ee-a158-97f8443fd730
# (35, 22)
# Saved metadata data at ./data/metadata/68c289fa-dbd4-11ee-a158-97f8443fd730.csv
# querying metadata for 88b0613a-d35d-11ee-b437-336917683bb8
# (21, 17)
# Saved metadata data at ./data/metadata/88b0613a-d35d-11ee-b437-336917683bb8.csv
# querying metadata for f9d62032-db2a-11ee-a158-97f8443fd730
# (33, 22)
# Saved metadata data at ./data/metadata/f9d62032-db2a-11ee-a158-97f8443fd730.csv
# querying metadata for 90101c36-a621-11ee-88ec-eb6a8d5269b4
# (8, 17)
# Saved metadata data at ./data/metadata/90101c36-a621-11ee-88ec-eb6a8d5269b4.csv
# querying metadata for 39ba7438-d0d5-11ee-9435-f7e542e2436c
# (34, 22)
# Saved metadata data at ./data/metadata/39ba7438-d0d5-11ee-9435-f7e542e2436c.csv
# querying metadata for 06cbdbc0-db4d-11ee-a158-97f8443fd730
# (35, 22)
# Saved metadata data at ./data/metadata/06cbdbc0-db4d-11ee-a158-97f8443fd730.csv
# querying metadata for f6ac3c82-a445-11ee-88ec-eb6a8d5269b4
# (25, 17)
# Saved metadata data at ./data/metadata/f6ac3c82-a445-11ee-88ec-eb6a8d5269b4.csv
# querying metadata for da853e0c-a10f-11ee-981c-d126ddbe9afa
# (36, 17)
# Saved metadata data at ./data/metadata/da853e0c-a10f-11ee-981c-d126ddbe9afa.csv
# querying metadata for 1bbbfbae-c839-11ee-a7fc-dd032dba19e8
# (18, 17)
# Saved metadata data at ./data/metadata/1bbbfbae-c839-11ee-a7fc-dd032dba19e8.csv
# querying metadata for ed352100-cba0-11ee-909c-e1dc60cf66f9
# (19, 17)
# Saved metadata data at ./data/metadata/ed352100-cba0-11ee-909c-e1dc60cf66f9.csv
